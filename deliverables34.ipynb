# %%
# %pip install wbdata
# %pip install pandas-datareader

import numpy as np
import pandas as pd
import wbdata
from pandas_datareader import wb
import matplotlib.pyplot as plt
# Out:
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Downloading dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.10.23)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.1
#     Uninstalling cachetools-6.2.1:
#       Successfully uninstalled cachetools-6.2.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.9.0 tzlocal-5.3.1 wbdata-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas-datareader
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting lxml (from pandas-datareader)
#   Using cached lxml-6.0.2-cp311-cp311-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pandas>=0.23 in /srv/conda/lib/python3.11/site-packages (from pandas-datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /srv/conda/lib/python3.11/site-packages (from pandas-datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.23.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.11/site-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.19.0->pandas-datareader) (2025.10.5)
# Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Using cached lxml-6.0.2-cp311-cp311-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
# Installing collected packages: lxml, pandas-datareader
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas-datareader]
# Successfully installed lxml-6.0.2 pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.
# Key '-7832316405915325519' not in persistent cache.
# Key '-7578078993365999556' not in persistent cache.
# Key '7087467893707253541' not in persistent cache.
# Key '-5539362124463864408' not in persistent cache.
# Key '-2728358736946578441' not in persistent cache.
# Key '-2020292609915980139' not in persistent cache.
# Key '790710777601305828' not in persistent cache.
# Key '9143623800482769651' not in persistent cache.
# Key '-2679313296123573028' not in persistent cache.
# Key '-56970687885553580' not in persistent cache.
# Key '6464345021467255585' not in persistent cache.
# Key '-6859562989595884584' not in persistent cache.
# Key '5437878701788675028' not in persistent cache.
# Key '-161089420728357571' not in persistent cache.
# Key '2479420580490433352' not in persistent cache.
# Key '-8068239184818926780' not in persistent cache.
# Key '-4803407082820368474' not in persistent cache.
# Key '-4640075600953571204' not in persistent cache.
# Key '-1960797292353458056' not in persistent cache.
# Key '-1706559879804132093' not in persistent cache.
# Key '1558272222194426213' not in persistent cache.
# Key '2979828894748491752' not in persistent cache.
# Key '3143160376615289022' not in persistent cache.
# Key '-547130879338480804' not in persistent cache.
# Key '6662229891163173291' not in persistent cache.
# Key '-3431601159664914502' not in persistent cache.
# Key '-1206151565546073693' not in persistent cache.
# Key '5814548425676313883' not in persistent cache.
# Key '2546237329172539672' not in persistent cache.
# Key '-6379313298906232369' not in persistent cache.
# Key '1519771009493959115' not in persistent cache.
# Key '319160269961294644' not in persistent cache.
# Key '2959670271180085567' not in persistent cache.
# Key '-7587989494129274565' not in persistent cache.
# Key '-4323157392130716259' not in persistent cache.
# Key '-4159825910263918989' not in persistent cache.
# Key '-1480547601663805841' not in persistent cache.
# Key '-5624667572098848006' not in persistent cache.
# Key '2038521912884078428' not in persistent cache.
# Key '3460078585438143967' not in persistent cache.
# Key '3623410067304941237' not in persistent cache.
# Key '-66881188648828589' not in persistent cache.
# Key '7142479581852825506' not in persistent cache.
# Key '-2951351468975262287' not in persistent cache.
# Key '-725901874856421478' not in persistent cache.
# Key '6294798116365966098' not in persistent cache.
# Key '6706841397002144035' not in persistent cache.
# Key '-2218709231076628006' not in persistent cache.
# Key '-5720339707751131313' not in persistent cache.
# Key '4479764337790899007' not in persistent cache.
# Key '2721916956025321802' not in persistent cache.
# Key '-7825742809284038330' not in persistent cache.
# Key '-162553324301111896' not in persistent cache.
# Key '7046807446200542199' not in persistent cache.
# Key '2680056466165798522' not in persistent cache.
# Key '-1464063504269243643' not in persistent cache.
# Key '6199125980713682791' not in persistent cache.
# Key '7620682653267748330' not in persistent cache.
# Key '-3616700649940149191' not in persistent cache.
# Key '-7306991905893919017' not in persistent cache.
# Key '-7143660424027121747' not in persistent cache.
# Key '8255281887489198901' not in persistent cache.
# Key '-7966012592101511906' not in persistent cache.
# Key '-945312600879124330' not in persistent cache.
# Key '347133759154407184' not in persistent cache.
# Key '-8578416868924364857' not in persistent cache.
# Key '6366696728110683452' not in persistent cache.
# Key '5166085988578018981' not in persistent cache.
# Key '-3637790681822415049' not in persistent cache.
# Key '-7139421158496918356' not in persistent cache.
# Key '-6522260962148848747' not in persistent cache.
# Key '687099808352805348' not in persistent cache.
# Key '3366378116952918496' not in persistent cache.
# Key '-7823771142116980494' not in persistent cache.
# Key '-160581657134054060' not in persistent cache.
# Key '1260975015420011479' not in persistent cache.
# Key '8470335785921665574' not in persistent cache.
# Key '4780044529967895748' not in persistent cache.
# Key '-6457338773240001773' not in persistent cache.
# Key '1895574249641462050' not in persistent cache.
# Key '4121023843760302859' not in persistent cache.
# Key '-7305020238726861181' not in persistent cache.
# Key '2974741019323254878' not in persistent cache.
# Key '-5950809608755517163' not in persistent cache.
# Key '8994303988279531146' not in persistent cache.
# Key '747663960112009850' not in persistent cache.
# Key '-1010183421653567355' not in persistent cache.
# Key '6888900886746624129' not in persistent cache.
# Key '-3894653701980001053' not in persistent cache.
# Key '3314707068521653042' not in persistent cache.
# Key '-1052043911513090635' not in persistent cache.
# Key '-5196163881948132800' not in persistent cache.
# Key '2467025603034793634' not in persistent cache.
# Key '3888582275588859173' not in persistent cache.
# Key '-7348801027619038348' not in persistent cache.
# Key '7407651790136743442' not in persistent cache.
# Key '3172625889019172584' not in persistent cache.
# Key '4523181509810309744' not in persistent cache.
# Key '-297398184705706272' not in persistent cache.
# Key '-9075770361542381615' not in persistent cache.
# Key '-6303265349566598021' not in persistent cache.
# Key '-7309434211379822239' not in persistent cache.
# Key '2365532832863452619' not in persistent cache.
# Key '4202215231984230426' not in persistent cache.
# Key '1661550264527754187' not in persistent cache.
# Key '6784386327174165634' not in persistent cache.
# Key '7681113233484030455' not in persistent cache.
# Key '2082145110966997856' not in persistent cache.
# Key '-2323374176449068046' not in persistent cache.
# Key '-5825004653123571353' not in persistent cache.
# Key '8840542233949681744' not in persistent cache.
# Key '-2396841069258215777' not in persistent cache.
# Key '282437239341897371' not in persistent cache.
# Key '-6509354636743633491' not in persistent cache.

# %%
age_ranges = []

for i in np.arange(0, 80, 5):
    age_ranges.append({'code': f"{i:02d}{i + 4:02d}", 
                       'label': f"{i} - {i + 4}"
                      })
    
age_ranges.append({'code': '80UP', 
                   'label': '80+'})
print(age_ranges)
# Out:
# [{'code': '0004', 'label': '0 - 4'}, {'code': '0509', 'label': '5 - 9'}, {'code': '1014', 'label': '10 - 14'}, {'code': '1519', 'label': '15 - 19'}, {'code': '2024', 'label': '20 - 24'}, {'code': '2529', 'label': '25 - 29'}, {'code': '3034', 'label': '30 - 34'}, {'code': '3539', 'label': '35 - 39'}, {'code': '4044', 'label': '40 - 44'}, {'code': '4549', 'label': '45 - 49'}, {'code': '5054', 'label': '50 - 54'}, {'code': '5559', 'label': '55 - 59'}, {'code': '6064', 'label': '60 - 64'}, {'code': '6569', 'label': '65 - 69'}, {'code': '7074', 'label': '70 - 74'}, {'code': '7579', 'label': '75 - 79'}, {'code': '80UP', 'label': '80+'}]

# %%
male_variables = {f"SP.POP.{b['code']}.MA": f"Males {b['label']}" for b in age_ranges}
female_variables = {f"SP.POP.{b['code']}.FE": f"Females {b['label']}" for b in age_ranges}

variables = {}

variables.update(male_variables)
variables.update(female_variables)

print(variables)
# Out:
# {'SP.POP.0004.MA': 'Males 0 - 4', 'SP.POP.0509.MA': 'Males 5 - 9', 'SP.POP.1014.MA': 'Males 10 - 14', 'SP.POP.1519.MA': 'Males 15 - 19', 'SP.POP.2024.MA': 'Males 20 - 24', 'SP.POP.2529.MA': 'Males 25 - 29', 'SP.POP.3034.MA': 'Males 30 - 34', 'SP.POP.3539.MA': 'Males 35 - 39', 'SP.POP.4044.MA': 'Males 40 - 44', 'SP.POP.4549.MA': 'Males 45 - 49', 'SP.POP.5054.MA': 'Males 50 - 54', 'SP.POP.5559.MA': 'Males 55 - 59', 'SP.POP.6064.MA': 'Males 60 - 64', 'SP.POP.6569.MA': 'Males 65 - 69', 'SP.POP.7074.MA': 'Males 70 - 74', 'SP.POP.7579.MA': 'Males 75 - 79', 'SP.POP.80UP.MA': 'Males 80+', 'SP.POP.0004.FE': 'Females 0 - 4', 'SP.POP.0509.FE': 'Females 5 - 9', 'SP.POP.1014.FE': 'Females 10 - 14', 'SP.POP.1519.FE': 'Females 15 - 19', 'SP.POP.2024.FE': 'Females 20 - 24', 'SP.POP.2529.FE': 'Females 25 - 29', 'SP.POP.3034.FE': 'Females 30 - 34', 'SP.POP.3539.FE': 'Females 35 - 39', 'SP.POP.4044.FE': 'Females 40 - 44', 'SP.POP.4549.FE': 'Females 45 - 49', 'SP.POP.5054.FE': 'Females 50 - 54', 'SP.POP.5559.FE': 'Females 55 - 59', 'SP.POP.6064.FE': 'Females 60 - 64', 'SP.POP.6569.FE': 'Females 65 - 69', 'SP.POP.7074.FE': 'Females 70 - 74', 'SP.POP.7579.FE': 'Females 75 - 79', 'SP.POP.80UP.FE': 'Females 80+'}

# %%
def population_df(countries, start, end):
    
    df = wb.download(indicator = variables, 
                     country = countries, 
                     start = start, 
                     end = end)
    
    df = df.rename(columns = variables)
    
    df = df.sort_index()
    
    return df

pop = population_df(['USA'], start = 2000, end = 2020)
pop.head()
# Out:
# /tmp/ipykernel_72/1996821281.py:3: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = wb.download(indicator = variables,
#                     Males 0 - 4  Males 5 - 9  Males 10 - 14  Males 15 - 19  \
# country       year
# United States 2000      9771939     10335718       10553412       10509013
#               2001      9843473     10185442       10741746       10606063
#               2002      9926071     10047860       10862596       10667781
#               2003     10004990      9952683       10902135       10752048
#               2004     10087732      9925601       10861255       10887805
#
#                     Males 20 - 24  Males 25 - 29  Males 30 - 34  \
# country       year
# United States 2000       10113115       10099438       10681709
#               2001       10381773        9934971       10716510
#               2002       10593144        9908339       10684970
#               2003       10753678       10017439       10581542
#               2004       10873838       10188229       10448447
#
#                     Males 35 - 39  Males 40 - 44  Males 45 - 49  ...  \
# country       year                                               ...
# United States 2000       11685873       11434350       10101752  ...
#               2001       11490531       11612386       10376690  ...
#               2002       11243072       11725204       10645567  ...
#               2003       10995463       11746971       10889716  ...
#               2004       10800389       11722118       11098720  ...
#
#                     Females 35 - 39  Females 40 - 44  Females 45 - 49  \
# country       year
# United States 2000         11230889         11275581         10162194
#               2001         11025682         11372211         10453769
#               2002         10780925         11433366         10722137
#               2003         10534846         11423398         10945036
#               2004         10337589         11384371         11127657
#
#                     Females 50 - 54  Females 55 - 59  Females 60 - 64  \
# country       year
# United States 2000          8950669          6977396          5596457
#               2001          9240314          7291983          5740996
#               2002          9399388          7710777          5984973
#               2003          9572435          8080769          6285001
#               2004          9818989          8439182          6561036
#
#                     Females 65 - 69  Females 70 - 74  Females 75 - 79  \
# country       year
# United States 2000          5030856          4783926          4247941
#               2001          5030189          4740535          4249963
#               2002          5054830          4695425          4231361
#               2003          5120835          4638729          4208188
#               2004          5215139          4609271          4179263
#
#                     Females 80+
# country       year
# United States 2000      6030376
#               2001      6131239
#               2002      6240916
#               2003      6339001
#               2004      6446416
#
# [5 rows x 34 columns]

# %%
def _age_sort_key(label):
    s = str(label)
    num = ''
    for character in s:
        if character.isdigit():
            num += character
        elif num:
            break
    return int(num) if num else 9999

def population_pyramid(df, country = None, year = None, title = None, ax = None):
    if country is not None and year is not None:
        row = df.loc[(country, str(year))]
    else:
        row = df.iloc[0]

    male_cols = [c for c in row.index if str(c).startswith('Males ')]
    female_cols = [c for c in row.index if str(c).startswith('Females ')]

    if len(male_cols) == 0 or len(female_cols) == 0:
        return ValueError('No columns starting with Males and Females')

    def age_label(column_name, prefix):
        return str(column_name)[len(prefix):]

    male_map = {age_label(c, 'Males '): c for c in male_cols}
    female_map = {age_label(c, 'Females '): c for c in female_cols}

    ages = sorted(set(male_map.keys()) & set(female_map.keys()), key = _age_sort_key)

    males = np.array([row[male_map[a]] if a in male_map else np.nan for a in ages], dtype=float)
    females = np.array([row[female_map[a]] if a in female_map else np.nan for a in ages], dtype=float)

    scale = 1e6
    males = males/scale
    females = females/scale

    males_plot = -males
    females_plot = females

    if ax is None:
        fig, ax = plt.subplots(figsize = (7, 6))

    y = np.arange(len(ages))
    ax.barh(y, males_plot, label = "Males")
    ax.barh(y, females_plot, label = "Females")

    ax.set_yticks(y)
    ax.set_yticklabels(ages)

    max_val = max(np.nanmax(males_plot), np.nanmax(females_plot)) if len(ages) else 1
    ax.set_xlim(-max_val * 1.1, max_val * 1.1)
    ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"{abs(int(x))}"))

    ax.axvline(0, linewidth=1)

    ax.set_xlabel("Population (millions)")
    ax.set_ylabel("Age group")

    if title is None:
        if country is not None:
            title = f"{country} Population Pyramid"
        else:
            title = "Population Pyramid"
    ax.set_title(title)

    ax.legend()
    return ax

# %%
population_pyramid(pop, country = 'United States', year = 2004)
# Out:
# <Axes: title={'center': 'United States Population Pyramid'}, xlabel='Population (millions)', ylabel='Age group'>
